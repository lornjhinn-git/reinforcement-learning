# %%
import Maze 
from train import *

MAZE_SIZE = 8
blocked_squares = [[i, i-1] for i in range(1,7)]
env = Maze.Maze(dimensions = [MAZE_SIZE, MAZE_SIZE], blocked = blocked_squares)
use_epsilon = 0.1
env.reset()
values = {}
rewards_list = []
steps_list = []
step = 0
last_path = []
first_path = []

# %%
env.reset()
position, goal_position = unique_starts(0)
start_position = position
env.position = np.asarray(position)
env.goal_position = np.asarray(goal_position)
current_state = env.compressed_state_rep()
print("position:", position, env.position)
print("goal position:", goal_position, env.goal_position)
print("current_state:\n", current_state)

# %%
action, action_v = policy(values, current_state, epsilon = use_epsilon, verbose=True)
total_reward = 0
step = 0
deltas = []
print("action:", action, "action_v:", action_v)

# %%
first_path.append(action)
first_path

# %% [markdown]
# # LOOP STARTS HERE

# %%
step +=1
reward = env.move(action)
total_reward += reward
next_state = env.compressed_state_rep()
print("reward:", reward)
print("total_reward:", total_reward)
print("next_state:")
print(next_state)

# %%
next_action, next_action_v = policy(values, next_state, epsilon = use_epsilon, verbose=True)
print("values:", values)
print("\nnext_state:")
print(next_state, "\n")
print("next_action:", next_action, "next_action_v:", next_action_v)

# %%
delta = next_action_v*GAMMA + reward - action_v
deltas.append(delta)
new_value = action_v + delta*alpha
update(current_state, action, new_value, values)
current_state = next_state
action = next_action
action_v = next_action_v

# %%
values

# %%
print(current_state)

# %% [markdown]
# **SARSA purchase insight test**

# %%
import numpy as np

# Define the state space
num_segments = 2
num_days = 7
num_pages = 4
state_space = np.zeros((num_segments, num_days, num_pages))

# Define the action space
num_prices = 10
num_times = 20
action_space = np.zeros((num_prices, num_times))

# Initialize the Q-values
Q = np.zeros((num_segments, num_days, num_pages, num_prices, num_times))

# %%
# Define the reward function
def reward(price, cost):
    return price - cost

# Define the SARSA algorithm
def sarsa(state, action, reward, next_state, next_action, alpha, gamma, epsilon):
    # Get the current Q-value
    q = Q[state[0], state[1], state[2], action[0], action[1]]
    
    # Get the next Q-value
    next_q = Q[next_state[0], next_state[1], next_state[2], next_action[0], next_action[1]]
    
    # Update the Q-value using SARSA
    delta = reward + gamma * next_q - q
    Q[state[0], state[1], state[2], action[0], action[1]] += alpha * delta
    
    # Choose the next action using epsilon-greedy policy
    if np.random.rand() < epsilon:
        next_action = np.random.randint(num_prices), np.random.randint(num_times)
    else:
        next_action = np.unravel_index(np.argmax(Q[next_state[0], next_state[1], next_state[2]]), (num_prices, num_times))
    
    return next_action

# %%
num_transactions = 1000
dataset = []
testset = []

for i in range(num_transactions):
    # Generate a random state
    segment = np.random.randint(num_segments)
    day = np.random.randint(num_days)
    page = np.random.randint(num_pages)
    state = (segment, day, page)

    # Choose an action using epsilon-greedy policy
    if np.random.rand() < 0.1:
        price = np.random.randint(num_prices)
        time = np.random.randint(num_times)
    else:
        price, time = np.unravel_index(np.argmax(Q[segment, day, page]), (num_prices, num_times))
        
    action = (price, time)

    # Generate a random cost
    cost = np.random.randint(10, 101)
    
    # Compute the reward
    reward = action[0] - cost
    
    # Add the data to the dataset or testset
    if i < num_transactions * 0.8:
        dataset.append([segment, day, page, price, time, cost])
    else:
        testset.append([segment, day, page, price, time, cost])

# %%
data = [[segment, day, page, price, time, cost] for segment, day, page, price, time, cost in dataset]
alpha = 0.1
gamma = 0.9
epsilon = 0.1

# %%
data[:5]

# %%
for i in range(len(data)-1):
    state = tuple(data[i][:3])
    action = tuple(data[i][3:5])
    cost = data[i][5]
    next_state = tuple(data[i+1][:3])
    next_action = tuple(data[i+1][3:5])
    r = reward(action[0], cost)
    
    print("State:", state)
    print("Action:", action)
    print("Cost:", cost)
    print("Rewards:", r)
    print("Next_State:", next_state)
    print("Next_Action:", next_action, "\n")
    sarsa(state, action, r, next_state, next_action, alpha, gamma, epsilon)

# %%
Q[0][0].shape

# %%
Q

# %%
testset

# %%
test_data = [[segment, day, page, price, time] for segment, day, page, price, time, cost in testset]
test_data[:5]

# %%
def get_state(test_data):
    state = test_data
    return state

# %%
state = get_state(test_data[0])
state

# %%
Q[1][6][0].shape

# %%
Q[1][6][0][0]

# %%
Q[1][6][0][1][1]

# %%
price_action = np.argmax(Q[1][6][0]) 
time_action = np.argmax(Q[1][6][0][0]) 
print(price_action, time_action)

# %%
Q.shape

# %%
import numpy as np

# Define the state space
num_segments = 2
num_days = 7
num_pages = 4
state_space = np.zeros((num_segments, num_days, num_pages))

# Define the action space
num_prices = 10
num_times = 20
action_space = np.zeros((num_times, num_prices))

# Initialize the Q-values
Q = np.zeros((num_segments, num_days, num_pages, num_times, num_prices))

# %%
# Define the reward function
def reward(price, cost):
    return price - cost

# Define the SARSA algorithm
def sarsa(state, action, reward, next_state, next_action, alpha, gamma, epsilon):
    # Get the current Q-value
    q = Q[state[0], state[1], state[2], action[0], action[1]]
    
    # Get the next Q-value
    next_q = Q[next_state[0], next_state[1], next_state[2], next_action[0], next_action[1]]
    
    # Update the Q-value using SARSA
    delta = reward + gamma * next_q - q
    Q[state[0], state[1], state[2], action[0], action[1]] += alpha * delta
    
    # Choose the next action using epsilon-greedy policy
    if np.random.rand() < epsilon:
        next_action = np.random.randint(num_times), np.random.randint(num_prices)
    else:
        next_action = np.unravel_index(np.argmax(Q[next_state[0], next_state[1], next_state[2]]), (num_times, num_prices))
    
    return next_action


# Generate the sample data
def generate_sample():
    num_transactions = 1000
    dataset = []
    testset = []

    for i in range(num_transactions):
        # Generate a random state
        segment = np.random.randint(num_segments)
        day = np.random.randint(num_days)
        page = np.random.randint(num_pages)
        state = (segment, day, page)
        
        # Choose an action using epsilon-greedy policy
        if np.random.rand() < 0.1:
            price = np.random.randint(num_prices)
            time = np.random.randint(num_times)
        else:
            time, price = np.unravel_index(np.argmax(Q[segment, day, page]), (num_times, num_prices))
        action = (time, price)
        
        # Generate a random cost
        cost = np.random.randint(10, 101)
        
        # Compute the reward
        reward = action[0] - cost
        
        # Add the data to the dataset or testset
        if i < num_transactions * 0.8:
            dataset.append([segment, day, page, time, price, cost])
        else:
            testset.append([segment, day, page, time, price, cost])

        
    return dataset, testset


dataset, testset = generate_sample()

# %%
# Train the SARSA algorithm on the data
data = [[segment, day, page, time, price, cost] for segment, day, page, time, price, cost in dataset]
alpha = 0.1
gamma = 0.9
epsilon = 0.1

# %%
for i in range(len(data)-1):
    state = tuple(data[i][:3])
    action = tuple(data[i][3:5])
    cost = data[i][5]
    next_state = tuple(data[i+1][:3])
    next_action = tuple(data[i+1][3:5])
    r = reward(action[0], cost)
    
    sarsa(state, action, r, next_state, next_action, alpha, gamma, epsilon)

# %%
# Evaluate the SARSA algorithm on the test data
test_data = [[segment, day, page, time, price, cost] for segment, day, page, time, price, cost in testset]
total_reward = 0

for i in range(len(test_data)-1):
    state = tuple(test_data[i][:3])
    action = tuple(test_data[i][3:5])
    cost = test_data[i][5]
    next_state = tuple(test_data[i+1][:3])
    next_action = tuple(test_data[i+1][3:5])
    r = reward(action[0], cost)
    total_reward += r
    
    sarsa(state, action, r, next_state, next_action, alpha, gamma, epsilon)
    print("State:", state)
    print("Action:", action)
    print("Cost:", cost)
    print("Rewards:", r)
    print("Next_State:", next_state)
    print("Next_Action:", next_action, "\n")

print("Total reward: ", total_reward)
# Out:
# State: (0, 0, 2)
# Action: (0, 0)
# Cost: 20
# Rewards: -20
# Next_State: (1, 1, 0)
# Next_Action: (0, 0)
#
# State: (1, 1, 0)
# Action: (0, 0)
# Cost: 63
# Rewards: -63
# Next_State: (0, 0, 2)
# Next_Action: (9, 8)
#
# State: (0, 0, 2)
# Action: (9, 8)
# Cost: 18
# Rewards: -9
# Next_State: (1, 5, 2)
# Next_Action: (0, 0)
#
# State: (1, 5, 2)
# Action: (0, 0)
# Cost: 92
# Rewards: -92
# Next_State: (0, 2, 3)
# Next_Action: (0, 0)
#
# State: (0, 2, 3)
# Action: (0, 0)
# Cost: 88
# Rewards: -88
# Next_State: (1, 6, 1)
# Next_Action: (0, 0)
#
# State: (1, 6, 1)
# Action: (0, 0)
# Cost: 60
# Rewards: -60
# Next_State: (1, 2, 1)
# Next_Action: (0, 0)
#
# State: (1, 2, 1)
# Action: (0, 0)
# Cost: 67
# Rewards: -67
# Next_State: (0, 2, 1)
# Next_Action: (0, 0)
#
# State: (0, 2, 1)
# Action: (0, 0)
# Cost: 44
# Rewards: -44
# Next_State: (0, 4, 2)
# Next_Action: (0, 0)
#
# State: (0, 4, 2)
# Action: (0, 0)
# Cost: 41
# Rewards: -41
# Next_State: (0, 0, 3)
# Next_Action: (0, 0)
#
# State: (0, 0, 3)
# Action: (0, 0)
# Cost: 19
# Rewards: -19
# Next_State: (1, 5, 1)
# Next_Action: (0, 0)
#
# State: (1, 5, 1)
# Action: (0, 0)
# Cost: 57
# Rewards: -57
# Next_State: (0, 6, 3)
# Next_Action: (0, 0)
#
# State: (0, 6, 3)
# Action: (0, 0)
# Cost: 97
# Rewards: -97
# Next_State: (1, 2, 1)
# Next_Action: (1, 4)
#
# State: (1, 2, 1)
# Action: (1, 4)
# Cost: 26
# Rewards: -25
# Next_State: (0, 3, 0)
# Next_Action: (0, 0)
#
# State: (0, 3, 0)
# Action: (0, 0)
# Cost: 70
# Rewards: -70
# Next_State: (1, 1, 0)
# Next_Action: (0, 0)
#
# State: (1, 1, 0)
# Action: (0, 0)
# Cost: 69
# Rewards: -69
# Next_State: (1, 2, 0)
# Next_Action: (0, 0)
#
# State: (1, 2, 0)
# Action: (0, 0)
# Cost: 87
# Rewards: -87
# Next_State: (0, 5, 2)
# Next_Action: (0, 0)
#
# State: (0, 5, 2)
# Action: (0, 0)
# Cost: 69
# Rewards: -69
# Next_State: (0, 4, 2)
# Next_Action: (0, 0)
#
# State: (0, 4, 2)
# Action: (0, 0)
# Cost: 29
# Rewards: -29
# Next_State: (1, 3, 1)
# Next_Action: (0, 0)
#
# State: (1, 3, 1)
# Action: (0, 0)
# Cost: 61
# Rewards: -61
# Next_State: (0, 5, 1)
# Next_Action: (0, 0)
#
# State: (0, 5, 1)
# Action: (0, 0)
# Cost: 68
# Rewards: -68
# Next_State: (1, 5, 2)
# Next_Action: (0, 0)
#
# State: (1, 5, 2)
# Action: (0, 0)
# Cost: 29
# Rewards: -29
# Next_State: (0, 1, 0)
# Next_Action: (0, 0)
#
# State: (0, 1, 0)
# Action: (0, 0)
# Cost: 22
# Rewards: -22
# Next_State: (1, 5, 3)
# Next_Action: (0, 0)
#
# State: (1, 5, 3)
# Action: (0, 0)
# Cost: 40
# Rewards: -40
# Next_State: (1, 5, 2)
# Next_Action: (0, 0)
#
# State: (1, 5, 2)
# Action: (0, 0)
# Cost: 24
# Rewards: -24
# Next_State: (0, 0, 2)
# Next_Action: (0, 0)
#
# State: (0, 0, 2)
# Action: (0, 0)
# Cost: 73
# Rewards: -73
# Next_State: (0, 0, 3)
# Next_Action: (0, 0)
#
# State: (0, 0, 3)
# Action: (0, 0)
# Cost: 98
# Rewards: -98
# Next_State: (0, 6, 1)
# Next_Action: (0, 0)
#
# State: (0, 6, 1)
# Action: (0, 0)
# Cost: 19
# Rewards: -19
# Next_State: (0, 6, 2)
# Next_Action: (0, 0)
#
# State: (0, 6, 2)
# Action: (0, 0)
# Cost: 50
# Rewards: -50
# Next_State: (0, 2, 1)
# Next_Action: (0, 0)
#
# State: (0, 2, 1)
# Action: (0, 0)
# Cost: 43
# Rewards: -43
# Next_State: (1, 1, 1)
# Next_Action: (0, 0)
#
# State: (1, 1, 1)
# Action: (0, 0)
# Cost: 35
# Rewards: -35
# Next_State: (1, 4, 0)
# Next_Action: (0, 0)
#
# State: (1, 4, 0)
# Action: (0, 0)
# Cost: 48
# Rewards: -48
# Next_State: (1, 5, 3)
# Next_Action: (0, 0)
#
# State: (1, 5, 3)
# Action: (0, 0)
# Cost: 62
# Rewards: -62
# Next_State: (1, 4, 1)
# Next_Action: (0, 0)
#
# State: (1, 4, 1)
# Action: (0, 0)
# Cost: 45
# Rewards: -45
# Next_State: (1, 3, 3)
# Next_Action: (0, 0)
#
# State: (1, 3, 3)
# Action: (0, 0)
# Cost: 41
# Rewards: -41
# Next_State: (0, 0, 2)
# Next_Action: (0, 0)
#
# State: (0, 0, 2)
# Action: (0, 0)
# Cost: 81
# Rewards: -81
# Next_State: (0, 4, 2)
# Next_Action: (0, 0)
#
# State: (0, 4, 2)
# Action: (0, 0)
# Cost: 14
# Rewards: -14
# Next_State: (0, 5, 2)
# Next_Action: (0, 0)
#
# State: (0, 5, 2)
# Action: (0, 0)
# Cost: 71
# Rewards: -71
# Next_State: (1, 3, 2)
# Next_Action: (0, 0)
#
# State: (1, 3, 2)
# Action: (0, 0)
# Cost: 33
# Rewards: -33
# Next_State: (0, 6, 3)
# Next_Action: (0, 0)
#
# State: (0, 6, 3)
# Action: (0, 0)
# Cost: 49
# Rewards: -49
# Next_State: (1, 2, 1)
# Next_Action: (0, 0)
#
# State: (1, 2, 1)
# Action: (0, 0)
# Cost: 96
# Rewards: -96
# Next_State: (0, 4, 1)
# Next_Action: (0, 0)
#
# State: (0, 4, 1)
# Action: (0, 0)
# Cost: 85
# Rewards: -85
# Next_State: (1, 1, 1)
# Next_Action: (0, 0)
#
# State: (1, 1, 1)
# Action: (0, 0)
# Cost: 50
# Rewards: -50
# Next_State: (1, 0, 2)
# Next_Action: (0, 0)
#
# State: (1, 0, 2)
# Action: (0, 0)
# Cost: 46
# Rewards: -46
# Next_State: (1, 6, 2)
# Next_Action: (0, 0)
#
# State: (1, 6, 2)
# Action: (0, 0)
# Cost: 63
# Rewards: -63
# Next_State: (1, 5, 2)
# Next_Action: (0, 0)
#
# State: (1, 5, 2)
# Action: (0, 0)
# Cost: 22
# Rewards: -22
# Next_State: (1, 1, 3)
# Next_Action: (0, 0)
#
# State: (1, 1, 3)
# Action: (0, 0)
# Cost: 66
# Rewards: -66
# Next_State: (0, 3, 3)
# Next_Action: (0, 0)
#
# State: (0, 3, 3)
# Action: (0, 0)
# Cost: 98
# Rewards: -98
# Next_State: (1, 4, 0)
# Next_Action: (0, 0)
#
# State: (1, 4, 0)
# Action: (0, 0)
# Cost: 43
# Rewards: -43
# Next_State: (1, 1, 3)
# Next_Action: (9, 3)
#
# State: (1, 1, 3)
# Action: (9, 3)
# Cost: 22
# Rewards: -13
# Next_State: (1, 3, 3)
# Next_Action: (0, 0)
#
# State: (1, 3, 3)
# Action: (0, 0)
# Cost: 41
# Rewards: -41
# Next_State: (0, 5, 3)
# Next_Action: (0, 0)
#
# State: (0, 5, 3)
# Action: (0, 0)
# Cost: 74
# Rewards: -74
# Next_State: (1, 0, 3)
# Next_Action: (0, 0)
#
# State: (1, 0, 3)
# Action: (0, 0)
# Cost: 45
# Rewards: -45
# Next_State: (1, 1, 3)
# Next_Action: (0, 0)
#
# State: (1, 1, 3)
# Action: (0, 0)
# Cost: 55
# Rewards: -55
# Next_State: (1, 0, 0)
# Next_Action: (2, 2)
#
# State: (1, 0, 0)
# Action: (2, 2)
# Cost: 56
# Rewards: -54
# Next_State: (0, 4, 1)
# Next_Action: (0, 0)
#
# State: (0, 4, 1)
# Action: (0, 0)
# Cost: 65
# Rewards: -65
# Next_State: (1, 6, 3)
# Next_Action: (14, 9)
#
# State: (1, 6, 3)
# Action: (14, 9)
# Cost: 73
# Rewards: -59
# Next_State: (1, 1, 3)
# Next_Action: (0, 0)
#
# State: (1, 1, 3)
# Action: (0, 0)
# Cost: 44
# Rewards: -44
# Next_State: (1, 3, 2)
# Next_Action: (0, 0)
#
# State: (1, 3, 2)
# Action: (0, 0)
# Cost: 63
# Rewards: -63
# Next_State: (0, 5, 2)
# Next_Action: (0, 0)
#
# State: (0, 5, 2)
# Action: (0, 0)
# Cost: 43
# Rewards: -43
# Next_State: (0, 6, 3)
# Next_Action: (0, 0)
#
# State: (0, 6, 3)
# Action: (0, 0)
# Cost: 52
# Rewards: -52
# Next_State: (0, 1, 0)
# Next_Action: (0, 0)
#
# State: (0, 1, 0)
# Action: (0, 0)
# Cost: 59
# Rewards: -59
# Next_State: (1, 3, 3)
# Next_Action: (0, 0)
#
# State: (1, 3, 3)
# Action: (0, 0)
# Cost: 63
# Rewards: -63
# Next_State: (0, 2, 1)
# Next_Action: (0, 0)
#
# State: (0, 2, 1)
# Action: (0, 0)
# Cost: 93
# Rewards: -93
# Next_State: (1, 6, 2)
# Next_Action: (0, 0)
#
# State: (1, 6, 2)
# Action: (0, 0)
# Cost: 79
# Rewards: -79
# Next_State: (1, 4, 0)
# Next_Action: (0, 0)
#
# State: (1, 4, 0)
# Action: (0, 0)
# Cost: 11
# Rewards: -11
# Next_State: (0, 4, 1)
# Next_Action: (0, 0)
#
# State: (0, 4, 1)
# Action: (0, 0)
# Cost: 11
# Rewards: -11
# Next_State: (0, 5, 1)
# Next_Action: (0, 0)
#
# State: (0, 5, 1)
# Action: (0, 0)
# Cost: 94
# Rewards: -94
# Next_State: (1, 6, 2)
# Next_Action: (0, 0)
#
# State: (1, 6, 2)
# Action: (0, 0)
# Cost: 55
# Rewards: -55
# Next_State: (1, 2, 3)
# Next_Action: (0, 0)
#
# State: (1, 2, 3)
# Action: (0, 0)
# Cost: 40
# Rewards: -40
# Next_State: (1, 2, 2)
# Next_Action: (0, 0)
#
# State: (1, 2, 2)
# Action: (0, 0)
# Cost: 63
# Rewards: -63
# Next_State: (1, 3, 3)
# Next_Action: (0, 0)
#
# State: (1, 3, 3)
# Action: (0, 0)
# Cost: 36
# Rewards: -36
# Next_State: (1, 6, 0)
# Next_Action: (0, 0)
#
# State: (1, 6, 0)
# Action: (0, 0)
# Cost: 75
# Rewards: -75
# Next_State: (1, 4, 0)
# Next_Action: (1, 0)
#
# State: (1, 4, 0)
# Action: (1, 0)
# Cost: 60
# Rewards: -59
# Next_State: (0, 6, 2)
# Next_Action: (0, 0)
#
# State: (0, 6, 2)
# Action: (0, 0)
# Cost: 82
# Rewards: -82
# Next_State: (1, 6, 3)
# Next_Action: (0, 0)
#
# State: (1, 6, 3)
# Action: (0, 0)
# Cost: 21
# Rewards: -21
# Next_State: (0, 3, 3)
# Next_Action: (16, 0)
#
# State: (0, 3, 3)
# Action: (16, 0)
# Cost: 75
# Rewards: -59
# Next_State: (1, 3, 3)
# Next_Action: (0, 0)
#
# State: (1, 3, 3)
# Action: (0, 0)
# Cost: 29
# Rewards: -29
# Next_State: (1, 0, 0)
# Next_Action: (0, 0)
#
# State: (1, 0, 0)
# Action: (0, 0)
# Cost: 75
# Rewards: -75
# Next_State: (0, 5, 2)
# Next_Action: (0, 0)
#
# State: (0, 5, 2)
# Action: (0, 0)
# Cost: 45
# Rewards: -45
# Next_State: (0, 2, 3)
# Next_Action: (0, 0)
#
# State: (0, 2, 3)
# Action: (0, 0)
# Cost: 92
# Rewards: -92
# Next_State: (1, 3, 0)
# Next_Action: (0, 0)
#
# State: (1, 3, 0)
# Action: (0, 0)
# Cost: 79
# Rewards: -79
# Next_State: (0, 2, 1)
# Next_Action: (13, 1)
#
# State: (0, 2, 1)
# Action: (13, 1)
# Cost: 55
# Rewards: -42
# Next_State: (0, 0, 0)
# Next_Action: (0, 0)
#
# State: (0, 0, 0)
# Action: (0, 0)
# Cost: 89
# Rewards: -89
# Next_State: (0, 0, 0)
# Next_Action: (0, 0)
#
# State: (0, 0, 0)
# Action: (0, 0)
# Cost: 66
# Rewards: -66
# Next_State: (1, 5, 0)
# Next_Action: (0, 0)
#
# State: (1, 5, 0)
# Action: (0, 0)
# Cost: 91
# Rewards: -91
# Next_State: (1, 6, 2)
# Next_Action: (0, 0)
#
# State: (1, 6, 2)
# Action: (0, 0)
# Cost: 59
# Rewards: -59
# Next_State: (0, 1, 2)
# Next_Action: (0, 0)
#
# State: (0, 1, 2)
# Action: (0, 0)
# Cost: 100
# Rewards: -100
# Next_State: (1, 6, 3)
# Next_Action: (0, 0)
#
# State: (1, 6, 3)
# Action: (0, 0)
# Cost: 19
# Rewards: -19
# Next_State: (0, 4, 3)
# Next_Action: (0, 0)
#
# State: (0, 4, 3)
# Action: (0, 0)
# Cost: 33
# Rewards: -33
# Next_State: (0, 0, 2)
# Next_Action: (0, 0)
#
# State: (0, 0, 2)
# Action: (0, 0)
# Cost: 98
# Rewards: -98
# Next_State: (0, 4, 3)
# Next_Action: (0, 0)
#
# State: (0, 4, 3)
# Action: (0, 0)
# Cost: 41
# Rewards: -41
# Next_State: (0, 5, 1)
# Next_Action: (0, 0)
#
# State: (0, 5, 1)
# Action: (0, 0)
# Cost: 65
# Rewards: -65
# Next_State: (0, 4, 0)
# Next_Action: (0, 0)
#
# State: (0, 4, 0)
# Action: (0, 0)
# Cost: 73
# Rewards: -73
# Next_State: (0, 2, 3)
# Next_Action: (0, 0)
#
# State: (0, 2, 3)
# Action: (0, 0)
# Cost: 48
# Rewards: -48
# Next_State: (1, 4, 2)
# Next_Action: (0, 0)
#
# State: (1, 4, 2)
# Action: (0, 0)
# Cost: 18
# Rewards: -18
# Next_State: (0, 1, 3)
# Next_Action: (0, 0)
#
# State: (0, 1, 3)
# Action: (0, 0)
# Cost: 100
# Rewards: -100
# Next_State: (0, 4, 2)
# Next_Action: (0, 0)
#
# State: (0, 4, 2)
# Action: (0, 0)
# Cost: 26
# Rewards: -26
# Next_State: (1, 5, 1)
# Next_Action: (0, 0)
#
# State: (1, 5, 1)
# Action: (0, 0)
# Cost: 15
# Rewards: -15
# Next_State: (0, 4, 0)
# Next_Action: (18, 7)
#
# State: (0, 4, 0)
# Action: (18, 7)
# Cost: 20
# Rewards: -2
# Next_State: (0, 5, 1)
# Next_Action: (0, 0)
#
# State: (0, 5, 1)
# Action: (0, 0)
# Cost: 83
# Rewards: -83
# Next_State: (0, 5, 0)
# Next_Action: (0, 0)
#
# State: (0, 5, 0)
# Action: (0, 0)
# Cost: 21
# Rewards: -21
# Next_State: (1, 1, 0)
# Next_Action: (0, 0)
#
# State: (1, 1, 0)
# Action: (0, 0)
# Cost: 21
# Rewards: -21
# Next_State: (1, 2, 1)
# Next_Action: (0, 0)
#
# State: (1, 2, 1)
# Action: (0, 0)
# Cost: 34
# Rewards: -34
# Next_State: (0, 0, 0)
# Next_Action: (0, 0)
#
# State: (0, 0, 0)
# Action: (0, 0)
# Cost: 78
# Rewards: -78
# Next_State: (0, 3, 0)
# Next_Action: (0, 0)
#
# State: (0, 3, 0)
# Action: (0, 0)
# Cost: 71
# Rewards: -71
# Next_State: (0, 3, 2)
# Next_Action: (0, 0)
#
# State: (0, 3, 2)
# Action: (0, 0)
# Cost: 16
# Rewards: -16
# Next_State: (1, 4, 2)
# Next_Action: (0, 0)
#
# State: (1, 4, 2)
# Action: (0, 0)
# Cost: 80
# Rewards: -80
# Next_State: (1, 4, 2)
# Next_Action: (15, 6)
#
# State: (1, 4, 2)
# Action: (15, 6)
# Cost: 98
# Rewards: -83
# Next_State: (1, 1, 1)
# Next_Action: (0, 0)
#
# State: (1, 1, 1)
# Action: (0, 0)
# Cost: 90
# Rewards: -90
# Next_State: (1, 3, 0)
# Next_Action: (0, 0)
#
# State: (1, 3, 0)
# Action: (0, 0)
# Cost: 67
# Rewards: -67
# Next_State: (0, 2, 0)
# Next_Action: (0, 0)
#
# State: (0, 2, 0)
# Action: (0, 0)
# Cost: 37
# Rewards: -37
# Next_State: (1, 2, 3)
# Next_Action: (0, 0)
#
# State: (1, 2, 3)
# Action: (0, 0)
# Cost: 49
# Rewards: -49
# Next_State: (1, 2, 0)
# Next_Action: (0, 0)
#
# State: (1, 2, 0)
# Action: (0, 0)
# Cost: 75
# Rewards: -75
# Next_State: (0, 1, 1)
# Next_Action: (0, 0)
#
# State: (0, 1, 1)
# Action: (0, 0)
# Cost: 46
# Rewards: -46
# Next_State: (0, 3, 0)
# Next_Action: (14, 9)
#
# State: (0, 3, 0)
# Action: (14, 9)
# Cost: 71
# Rewards: -57
# Next_State: (0, 3, 1)
# Next_Action: (0, 0)
#
# State: (0, 3, 1)
# Action: (0, 0)
# Cost: 47
# Rewards: -47
# Next_State: (1, 5, 3)
# Next_Action: (0, 0)
#
# State: (1, 5, 3)
# Action: (0, 0)
# Cost: 33
# Rewards: -33
# Next_State: (0, 4, 2)
# Next_Action: (10, 7)
#
# State: (0, 4, 2)
# Action: (10, 7)
# Cost: 33
# Rewards: -23
# Next_State: (0, 4, 0)
# Next_Action: (0, 0)
#
# State: (0, 4, 0)
# Action: (0, 0)
# Cost: 19
# Rewards: -19
# Next_State: (0, 3, 0)
# Next_Action: (0, 0)
#
# State: (0, 3, 0)
# Action: (0, 0)
# Cost: 31
# Rewards: -31
# Next_State: (0, 3, 0)
# Next_Action: (2, 9)
#
# State: (0, 3, 0)
# Action: (2, 9)
# Cost: 91
# Rewards: -89
# Next_State: (0, 6, 2)
# Next_Action: (0, 0)
#
# State: (0, 6, 2)
# Action: (0, 0)
# Cost: 73
# Rewards: -73
# Next_State: (0, 6, 1)
# Next_Action: (14, 4)
#
# State: (0, 6, 1)
# Action: (14, 4)
# Cost: 68
# Rewards: -54
# Next_State: (0, 0, 0)
# Next_Action: (18, 8)
#
# State: (0, 0, 0)
# Action: (18, 8)
# Cost: 34
# Rewards: -16
# Next_State: (0, 2, 0)
# Next_Action: (3, 5)
#
# State: (0, 2, 0)
# Action: (3, 5)
# Cost: 22
# Rewards: -19
# Next_State: (0, 1, 3)
# Next_Action: (0, 0)
#
# State: (0, 1, 3)
# Action: (0, 0)
# Cost: 18
# Rewards: -18
# Next_State: (1, 6, 1)
# Next_Action: (0, 0)
#
# State: (1, 6, 1)
# Action: (0, 0)
# Cost: 39
# Rewards: -39
# Next_State: (0, 3, 2)
# Next_Action: (0, 0)
#
# State: (0, 3, 2)
# Action: (0, 0)
# Cost: 81
# Rewards: -81
# Next_State: (0, 2, 3)
# Next_Action: (0, 0)
#
# State: (0, 2, 3)
# Action: (0, 0)
# Cost: 72
# Rewards: -72
# Next_State: (0, 3, 2)
# Next_Action: (0, 0)
#
# State: (0, 3, 2)
# Action: (0, 0)
# Cost: 68
# Rewards: -68
# Next_State: (1, 3, 1)
# Next_Action: (0, 0)
#
# State: (1, 3, 1)
# Action: (0, 0)
# Cost: 62
# Rewards: -62
# Next_State: (1, 5, 0)
# Next_Action: (0, 0)
#
# State: (1, 5, 0)
# Action: (0, 0)
# Cost: 73
# Rewards: -73
# Next_State: (0, 2, 1)
# Next_Action: (0, 0)
#
# State: (0, 2, 1)
# Action: (0, 0)
# Cost: 84
# Rewards: -84
# Next_State: (0, 0, 3)
# Next_Action: (0, 0)
#
# State: (0, 0, 3)
# Action: (0, 0)
# Cost: 30
# Rewards: -30
# Next_State: (0, 1, 1)
# Next_Action: (0, 0)
#
# State: (0, 1, 1)
# Action: (0, 0)
# Cost: 16
# Rewards: -16
# Next_State: (1, 1, 3)
# Next_Action: (0, 0)
#
# State: (1, 1, 3)
# Action: (0, 0)
# Cost: 93
# Rewards: -93
# Next_State: (1, 1, 1)
# Next_Action: (0, 0)
#
# State: (1, 1, 1)
# Action: (0, 0)
# Cost: 59
# Rewards: -59
# Next_State: (0, 6, 2)
# Next_Action: (0, 0)
#
# State: (0, 6, 2)
# Action: (0, 0)
# Cost: 61
# Rewards: -61
# Next_State: (0, 6, 0)
# Next_Action: (16, 4)
#
# State: (0, 6, 0)
# Action: (16, 4)
# Cost: 44
# Rewards: -28
# Next_State: (1, 3, 1)
# Next_Action: (0, 0)
#
# State: (1, 3, 1)
# Action: (0, 0)
# Cost: 55
# Rewards: -55
# Next_State: (0, 3, 2)
# Next_Action: (0, 0)
#
# State: (0, 3, 2)
# Action: (0, 0)
# Cost: 81
# Rewards: -81
# Next_State: (1, 4, 1)
# Next_Action: (0, 0)
#
# State: (1, 4, 1)
# Action: (0, 0)
# Cost: 33
# Rewards: -33
# Next_State: (1, 6, 0)
# Next_Action: (0, 0)
#
# State: (1, 6, 0)
# Action: (0, 0)
# Cost: 76
# Rewards: -76
# Next_State: (1, 6, 1)
# Next_Action: (0, 0)
#
# State: (1, 6, 1)
# Action: (0, 0)
# Cost: 70
# Rewards: -70
# Next_State: (0, 4, 3)
# Next_Action: (17, 7)
#
# State: (0, 4, 3)
# Action: (17, 7)
# Cost: 91
# Rewards: -74
# Next_State: (0, 2, 1)
# Next_Action: (0, 0)
#
# State: (0, 2, 1)
# Action: (0, 0)
# Cost: 89
# Rewards: -89
# Next_State: (0, 1, 0)
# Next_Action: (0, 0)
#
# State: (0, 1, 0)
# Action: (0, 0)
# Cost: 43
# Rewards: -43
# Next_State: (1, 3, 0)
# Next_Action: (0, 0)
#
# State: (1, 3, 0)
# Action: (0, 0)
# Cost: 81
# Rewards: -81
# Next_State: (0, 0, 2)
# Next_Action: (0, 0)
#
# State: (0, 0, 2)
# Action: (0, 0)
# Cost: 88
# Rewards: -88
# Next_State: (0, 2, 0)
# Next_Action: (0, 0)
#
# State: (0, 2, 0)
# Action: (0, 0)
# Cost: 12
# Rewards: -12
# Next_State: (0, 5, 1)
# Next_Action: (16, 7)
#
# State: (0, 5, 1)
# Action: (16, 7)
# Cost: 47
# Rewards: -31
# Next_State: (1, 6, 3)
# Next_Action: (0, 0)
#
# State: (1, 6, 3)
# Action: (0, 0)
# Cost: 28
# Rewards: -28
# Next_State: (1, 0, 1)
# Next_Action: (0, 0)
#
# State: (1, 0, 1)
# Action: (0, 0)
# Cost: 68
# Rewards: -68
# Next_State: (0, 1, 2)
# Next_Action: (0, 0)
#
# State: (0, 1, 2)
# Action: (0, 0)
# Cost: 85
# Rewards: -85
# Next_State: (1, 4, 2)
# Next_Action: (0, 0)
#
# State: (1, 4, 2)
# Action: (0, 0)
# Cost: 51
# Rewards: -51
# Next_State: (1, 3, 0)
# Next_Action: (0, 0)
#
# State: (1, 3, 0)
# Action: (0, 0)
# Cost: 26
# Rewards: -26
# Next_State: (1, 4, 1)
# Next_Action: (0, 0)
#
# State: (1, 4, 1)
# Action: (0, 0)
# Cost: 64
# Rewards: -64
# Next_State: (0, 1, 0)
# Next_Action: (0, 0)
#
# State: (0, 1, 0)
# Action: (0, 0)
# Cost: 100
# Rewards: -100
# Next_State: (1, 6, 2)
# Next_Action: (0, 0)
#
# State: (1, 6, 2)
# Action: (0, 0)
# Cost: 38
# Rewards: -38
# Next_State: (0, 2, 2)
# Next_Action: (0, 0)
#
# State: (0, 2, 2)
# Action: (0, 0)
# Cost: 100
# Rewards: -100
# Next_State: (1, 4, 1)
# Next_Action: (0, 0)
#
# State: (1, 4, 1)
# Action: (0, 0)
# Cost: 65
# Rewards: -65
# Next_State: (1, 6, 3)
# Next_Action: (0, 0)
#
# State: (1, 6, 3)
# Action: (0, 0)
# Cost: 77
# Rewards: -77
# Next_State: (1, 5, 0)
# Next_Action: (0, 0)
#
# State: (1, 5, 0)
# Action: (0, 0)
# Cost: 90
# Rewards: -90
# Next_State: (0, 1, 3)
# Next_Action: (0, 0)
#
# State: (0, 1, 3)
# Action: (0, 0)
# Cost: 84
# Rewards: -84
# Next_State: (1, 2, 3)
# Next_Action: (0, 0)
#
# State: (1, 2, 3)
# Action: (0, 0)
# Cost: 83
# Rewards: -83
# Next_State: (1, 6, 0)
# Next_Action: (5, 9)
#
# State: (1, 6, 0)
# Action: (5, 9)
# Cost: 19
# Rewards: -14
# Next_State: (0, 0, 0)
# Next_Action: (3, 5)
#
# State: (0, 0, 0)
# Action: (3, 5)
# Cost: 29
# Rewards: -26
# Next_State: (0, 6, 1)
# Next_Action: (0, 0)
#
# State: (0, 6, 1)
# Action: (0, 0)
# Cost: 65
# Rewards: -65
# Next_State: (0, 6, 1)
# Next_Action: (0, 0)
#
# State: (0, 6, 1)
# Action: (0, 0)
# Cost: 45
# Rewards: -45
# Next_State: (1, 6, 3)
# Next_Action: (0, 0)
#
# State: (1, 6, 3)
# Action: (0, 0)
# Cost: 70
# Rewards: -70
# Next_State: (1, 0, 1)
# Next_Action: (0, 0)
#
# State: (1, 0, 1)
# Action: (0, 0)
# Cost: 60
# Rewards: -60
# Next_State: (0, 1, 1)
# Next_Action: (0, 0)
#
# State: (0, 1, 1)
# Action: (0, 0)
# Cost: 67
# Rewards: -67
# Next_State: (0, 2, 0)
# Next_Action: (0, 0)
#
# State: (0, 2, 0)
# Action: (0, 0)
# Cost: 76
# Rewards: -76
# Next_State: (0, 3, 2)
# Next_Action: (0, 0)
#
# State: (0, 3, 2)
# Action: (0, 0)
# Cost: 40
# Rewards: -40
# Next_State: (0, 1, 0)
# Next_Action: (0, 0)
#
# State: (0, 1, 0)
# Action: (0, 0)
# Cost: 39
# Rewards: -39
# Next_State: (0, 5, 0)
# Next_Action: (0, 0)
#
# State: (0, 5, 0)
# Action: (0, 0)
# Cost: 61
# Rewards: -61
# Next_State: (0, 5, 1)
# Next_Action: (0, 0)
#
# State: (0, 5, 1)
# Action: (0, 0)
# Cost: 15
# Rewards: -15
# Next_State: (0, 2, 0)
# Next_Action: (16, 1)
#
# State: (0, 2, 0)
# Action: (16, 1)
# Cost: 96
# Rewards: -80
# Next_State: (1, 4, 2)
# Next_Action: (0, 0)
#
# State: (1, 4, 2)
# Action: (0, 0)
# Cost: 41
# Rewards: -41
# Next_State: (0, 2, 1)
# Next_Action: (0, 0)
#
# State: (0, 2, 1)
# Action: (0, 0)
# Cost: 67
# Rewards: -67
# Next_State: (1, 2, 0)
# Next_Action: (0, 0)
#
# State: (1, 2, 0)
# Action: (0, 0)
# Cost: 15
# Rewards: -15
# Next_State: (1, 1, 1)
# Next_Action: (0, 0)
#
# State: (1, 1, 1)
# Action: (0, 0)
# Cost: 85
# Rewards: -85
# Next_State: (0, 2, 0)
# Next_Action: (0, 0)
#
# State: (0, 2, 0)
# Action: (0, 0)
# Cost: 85
# Rewards: -85
# Next_State: (0, 1, 0)
# Next_Action: (0, 0)
#
# State: (0, 1, 0)
# Action: (0, 0)
# Cost: 60
# Rewards: -60
# Next_State: (1, 2, 2)
# Next_Action: (2, 1)
#
# State: (1, 2, 2)
# Action: (2, 1)
# Cost: 67
# Rewards: -65
# Next_State: (1, 1, 2)
# Next_Action: (11, 6)
#
# State: (1, 1, 2)
# Action: (11, 6)
# Cost: 19
# Rewards: -8
# Next_State: (1, 6, 0)
# Next_Action: (0, 0)
#
# State: (1, 6, 0)
# Action: (0, 0)
# Cost: 14
# Rewards: -14
# Next_State: (1, 3, 2)
# Next_Action: (8, 9)
#
# State: (1, 3, 2)
# Action: (8, 9)
# Cost: 41
# Rewards: -33
# Next_State: (0, 2, 1)
# Next_Action: (0, 0)
#
# State: (0, 2, 1)
# Action: (0, 0)
# Cost: 67
# Rewards: -67
# Next_State: (0, 6, 0)
# Next_Action: (0, 0)
#
# State: (0, 6, 0)
# Action: (0, 0)
# Cost: 10
# Rewards: -10
# Next_State: (0, 0, 1)
# Next_Action: (0, 0)
#
# State: (0, 0, 1)
# Action: (0, 0)
# Cost: 99
# Rewards: -99
# Next_State: (0, 4, 0)
# Next_Action: (0, 0)
#
# State: (0, 4, 0)
# Action: (0, 0)
# Cost: 22
# Rewards: -22
# Next_State: (0, 0, 3)
# Next_Action: (0, 0)
#
# State: (0, 0, 3)
# Action: (0, 0)
# Cost: 87
# Rewards: -87
# Next_State: (1, 3, 2)
# Next_Action: (0, 0)
#
# State: (1, 3, 2)
# Action: (0, 0)
# Cost: 27
# Rewards: -27
# Next_State: (0, 4, 3)
# Next_Action: (0, 9)
#
# State: (0, 4, 3)
# Action: (0, 9)
# Cost: 33
# Rewards: -33
# Next_State: (1, 6, 2)
# Next_Action: (0, 0)
#
# State: (1, 6, 2)
# Action: (0, 0)
# Cost: 77
# Rewards: -77
# Next_State: (0, 4, 1)
# Next_Action: (0, 0)
#
# State: (0, 4, 1)
# Action: (0, 0)
# Cost: 35
# Rewards: -35
# Next_State: (1, 4, 2)
# Next_Action: (0, 0)
#
# State: (1, 4, 2)
# Action: (0, 0)
# Cost: 60
# Rewards: -60
# Next_State: (1, 3, 0)
# Next_Action: (0, 0)
#
# State: (1, 3, 0)
# Action: (0, 0)
# Cost: 83
# Rewards: -83
# Next_State: (1, 3, 0)
# Next_Action: (0, 0)
#
# Total reward:  -10913

# %%
def choose_action(state):
    if random.uniform(0, 1) < epsilon:
        # Randomly choose an action
        action = np.random.choice((0, num_prices-1))
    else:
        # Choose the action with highest Q value
        action = np.argmax(Q[state[0]][state[1]][state[2]][state[3]][state[4]])
    return action


def train_sarsa(train_data):

    # Define variables to track performance validation
    prev_avg_reward = 0
    avg_reward = 100000
    num_episodes = 0
    
    # Train for multiple episodes until convergence
    while abs(avg_reward - prev_avg_reward) > 0.001:
        prev_avg_reward = avg_reward
        total_reward = 0
        print("Start SARSA")
        
        # Loop through all training data
        for i in range(len(train_data)-1):
            # Get current state and action
            state = get_state(train_data[i][0], train_data[i][1], train_data[i][2], train_data[i][3], train_data[i][4])
            action = choose_action(state)
            
            # Get next state and reward
            next_state = get_state(train_data[i+1][0], train_data[i+1][1], train_data[i+1][2], train_data[i+1][3], train_data[i+1][4])
            reward = train_data[i+1][5] * 0.1
            
            # Choose next action based on epsilon-greedy policy
            next_action = choose_action(next_state)
            
            # Update Q table
            td_error = reward + gamma * Q[next_state[0], next_state[1], next_state[2], next_state[3], next_state[4]] - Q[state[0], state[1], state[2], state[3], state[4]]
            Q[state[0], state[1], state[2], state[3], state[4]] += alpha * td_error
            
            total_reward += reward
        
        # Calculate average reward for the current episode
        avg_reward = total_reward / len(train_data)
        num_episodes += 1
        print("Episode:", num_episodes, "Average Reward:", avg_reward)
    
    return Q

# %%
num_prices = 10
Q = train_sarsa(data)
# Out:
# Start SARSA
# Episode: 1 Average Reward: 5.448499999999992
# Start SARSA
# Episode: 2 Average Reward: 5.448499999999992

# %%
state = get_state(test_data[i][0], test_data[i][1], test_data[i][2], test_data[i][3], test_data[i][4])
state
# Out:
# array([0, 0, 2, 0, 0], dtype=int64)

# %%
action = np.argmax(Q[state[0], state[1], state[2], state[3], state[4]])
action
# Out:
# 0

# %%
actual_prices = []
for segment, day, page, time, price, cost in test_data:
    actual_prices.append(price)

# %%
sarsa_prices = [] 
test_data = [[segment, day, page, time, price, cost] for segment, day, page, time, price, cost in testset]
for i in range(len(test_data)):
    # get the current state
    state = get_state(test_data[i][0], test_data[i][1], test_data[i][2], test_data[i][3], test_data[i][4])
    
    # get the best action from the SARSA model
    action = np.argmax(Q[state[0], state[1], state[2], state[3], state[4]])

    # print the action for the current state
    print("Action for state {}: {}".format(i+1, action))
    sarsa_prices.append(action)
# Out:
# Action for state 1: 0
# Action for state 2: 0
# Action for state 3: 0
# Action for state 4: 0
# Action for state 5: 0
# Action for state 6: 0
# Action for state 7: 0
# Action for state 8: 0
# Action for state 9: 0
# Action for state 10: 0
# Action for state 11: 0
# Action for state 12: 0
# Action for state 13: 0
# Action for state 14: 0
# Action for state 15: 0
# Action for state 16: 0
# Action for state 17: 0
# Action for state 18: 0
# Action for state 19: 0
# Action for state 20: 0
# Action for state 21: 0
# Action for state 22: 0
# Action for state 23: 0
# Action for state 24: 0
# Action for state 25: 0
# Action for state 26: 0
# Action for state 27: 0
# Action for state 28: 0
# Action for state 29: 0
# Action for state 30: 0
# Action for state 31: 0
# Action for state 32: 0
# Action for state 33: 0
# Action for state 34: 0
# Action for state 35: 0
# Action for state 36: 0
# Action for state 37: 0
# Action for state 38: 0
# Action for state 39: 0
# Action for state 40: 0
# Action for state 41: 0
# Action for state 42: 0
# Action for state 43: 0
# Action for state 44: 0
# Action for state 45: 0
# Action for state 46: 0
# Action for state 47: 0
# Action for state 48: 0
# Action for state 49: 0
# Action for state 50: 0
# Action for state 51: 0
# Action for state 52: 0
# Action for state 53: 0
# Action for state 54: 0
# Action for state 55: 0
# Action for state 56: 0
# Action for state 57: 0
# Action for state 58: 0
# Action for state 59: 0
# Action for state 60: 0
# Action for state 61: 0
# Action for state 62: 0
# Action for state 63: 0
# Action for state 64: 0
# Action for state 65: 0
# Action for state 66: 0
# Action for state 67: 0
# Action for state 68: 0
# Action for state 69: 0
# Action for state 70: 0
# Action for state 71: 0
# Action for state 72: 0
# Action for state 73: 0
# Action for state 74: 0
# Action for state 75: 0
# Action for state 76: 0
# Action for state 77: 0
# Action for state 78: 0
# Action for state 79: 0
# Action for state 80: 0
# Action for state 81: 0
# Action for state 82: 0
# Action for state 83: 0
# Action for state 84: 0
# Action for state 85: 0
# Action for state 86: 0
# Action for state 87: 0
# Action for state 88: 0
# Action for state 89: 0
# Action for state 90: 0
# Action for state 91: 0
# Action for state 92: 0
# Action for state 93: 0
# Action for state 94: 0
# Action for state 95: 0
# Action for state 96: 0
# Action for state 97: 0
# Action for state 98: 0
# Action for state 99: 0
# Action for state 100: 0
# Action for state 101: 0
# Action for state 102: 0
# Action for state 103: 0
# Action for state 104: 0
# Action for state 105: 0
# Action for state 106: 0
# Action for state 107: 0
# Action for state 108: 0
# Action for state 109: 0
# Action for state 110: 0
# Action for state 111: 0
# Action for state 112: 0
# Action for state 113: 0
# Action for state 114: 0
# Action for state 115: 0
# Action for state 116: 0
# Action for state 117: 0
# Action for state 118: 0
# Action for state 119: 0
# Action for state 120: 0
# Action for state 121: 0
# Action for state 122: 0
# Action for state 123: 0
# Action for state 124: 0
# Action for state 125: 0
# Action for state 126: 0
# Action for state 127: 0
# Action for state 128: 0
# Action for state 129: 0
# Action for state 130: 0
# Action for state 131: 0
# Action for state 132: 0
# Action for state 133: 0
# Action for state 134: 0
# Action for state 135: 0
# Action for state 136: 0
# Action for state 137: 0
# Action for state 138: 0
# Action for state 139: 0
# Action for state 140: 0
# Action for state 141: 0
# Action for state 142: 0
# Action for state 143: 0
# Action for state 144: 0
# Action for state 145: 0
# Action for state 146: 0
# Action for state 147: 0
# Action for state 148: 0
# Action for state 149: 0
# Action for state 150: 0
# Action for state 151: 0
# Action for state 152: 0
# Action for state 153: 0
# Action for state 154: 0
# Action for state 155: 0
# Action for state 156: 0
# Action for state 157: 0
# Action for state 158: 0
# Action for state 159: 0
# Action for state 160: 0
# Action for state 161: 0
# Action for state 162: 0
# Action for state 163: 0
# Action for state 164: 0
# Action for state 165: 0
# Action for state 166: 0
# Action for state 167: 0
# Action for state 168: 0
# Action for state 169: 0
# Action for state 170: 0
# Action for state 171: 0
# Action for state 172: 0
# Action for state 173: 0
# Action for state 174: 0
# Action for state 175: 0
# Action for state 176: 0
# Action for state 177: 0
# Action for state 178: 0
# Action for state 179: 0
# Action for state 180: 0
# Action for state 181: 0
# Action for state 182: 0
# Action for state 183: 0
# Action for state 184: 0
# Action for state 185: 0
# Action for state 186: 0
# Action for state 187: 0
# Action for state 188: 0
# Action for state 189: 0
# Action for state 190: 0
# Action for state 191: 0
# Action for state 192: 0
# Action for state 193: 0
# Action for state 194: 0
# Action for state 195: 0
# Action for state 196: 0
# Action for state 197: 0
# Action for state 198: 0
# Action for state 199: 0
# Action for state 200: 0

# %%
result = np.row_stack((actual_prices, sarsa_prices)).T 
result.shape
# Out:
# (200, 2)

# %%
def count_matching_columns(arr):
    match_counter = 0
    match_indices = []
    for i, row in enumerate(arr):
        if row[0] == row[1] and row[1] != 0:
            print(f"Matched {row[0]} and {row[1]}")
            match_counter += 1
            match_indices.append(i)
    return match_counter, match_indices

# %%
match_score = count_matching_columns(result)
match_score[0]
# Out:
# 0
